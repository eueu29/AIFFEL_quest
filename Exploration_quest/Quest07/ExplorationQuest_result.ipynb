# %% [markdown]
# # 전체 비교

# %% [markdown]
# **encoder-decoder 8-4 / U-Net 8-4 / Vgg16UNet 8-4 비교**
#
# iou : 0.8474698834511838-0.7916630810571875  / 0.8501262708667594 - 0.8354637450693675 / 0.8824816580942166 - 0.8496284703266106
# val_loss : 0.2425 - 0.3064 / 0.1789 - 0.2171 / 0.1293 - 0.1885
# val_dice_loss: 0.1863 - 0.2251 / 0.1348 - 0.1651 / 0.0959 - 0.1432
#
#
# 확실히 배치사이즈가 큰 쪽이 더 성능이 좋았고, vgg16UNet의 성능이 제일 좋았다.
# 하지만 출력 이미지 상은 큰 변화는 없었던것 같다

# %% [markdown]
# encoder-decoder 8
# ![image.png](attachment:27a589c3-250a-4179-b6a9-74d412618c2e.png)
# encoder-decoder 4
# ![image.png](attachment:1e3df530-44ad-4ee3-a686-a531fe03b81e.png)

# %% [markdown]
# UNet 8
# ![image.png](attachment:eca5612c-f36f-43a2-99cd-c61980b5c490.png)
# UNet 4
# ![image.png](attachment:c1a85539-bd26-4911-b86e-665f21665947.png)

# %% [markdown]
# VGG16UNet 8
# ![image.png](attachment:b96ad3fe-4a62-41fe-a509-1824f4467003.png)
# Vgg16UNet 4
# ![image.png](attachment:4961f79b-96c3-45aa-acbd-a7fe9721683f.png)

# %% [markdown]
# # 잘 안나온것들 경진대회

# %% [markdown]
# encoder-decoder 8
# ![image.png](attachment:db8d058c-f145-4488-9e91-136d5e4635bf.png)
# encoder-decoder 4
# ![image.png](attachment:729b68fe-089c-4cce-8137-3ef2b04b9870.png)

# %% [markdown]
# U-net 8
# ![image.png](attachment:859916ce-2a5c-4ee5-9f9a-288b123f0001.png)
# U-net 4
# ![image.png](attachment:1d252232-8a08-4651-ae2d-4a85609d0d54.png)

# %% [markdown]
# Vgg16UNet 8
# ![image.png](attachment:6a5b2068-d2d8-40d8-9765-ec11fff095d3.png)
# Vgg16UNet 4
# ![image.png](attachment:66d74468-9edc-4841-950d-dcf2f3b42a99.png)
