# %% [markdown]
# <a href="https://colab.research.google.com/github/eueu29/AIFFEL_quest/blob/main/Python_quest/Quest02/Quest_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# 파일 'read'로 불러오기
f = open("/content/drive/MyDrive/Colab Notebooks/Avengers.txt", "r")
readtext = f.read()

# 텍스트 소문자처리하기
# 특수기호를 replace를 사용하여 빈칸으로 변환해주기
lowertext = readtext.lower()
replacetext = lowertext.replace('.', ' ').replace(',', ' ').replace('?', ' ').replace("'", ' ').replace('-', '').replace('!', ' ').replace('/', ' ')\
.replace('^', ' ').replace('%', ' ').replace('\n', ' ').replace('ww', ' ').replace('(', ' ').replace(')', ' ')

# 띄어쓰기를 기준으로 split하도록 하기
# replacetext.split()을 사용하니 띄어쓰기 1개 기준으로 분할이 됨
# re 모듈을 import해서 re.split을 사용해주고
# r'\s+' = 하나 이상의 연속되는 공백 문자를 한개의 구분자로 취급해줌
splittext = re.split(r'\s+',replacetext)

# 2-gram 만들어서 빈 list에 추가하기
bigram_list = []
for i in range(len(splittext) -1):
  bigram_list.append(splittext[i]+splittext[i+1])
# print(bigram_list)

# for문을 통하여 2-gram list에서 반복되는 횟수를 value로 하는 딕셔너리 만들기
bigram_dict = {}
for bigram in bigram_list:
  if bigram not in bigram_dict.keys():
    bigram_dict[bigram] = 1
  elif bigram in bigram_dict.keys():
    bigram_dict[bigram] += 1
print(f"bigram 딕셔너리는 다음과 같습니다 : {bigram_dict}")

################## 내림차순 배열 후 max값 출력하기

# lambda 함수를 활용하여 value값을 내림차순으로 배열하기
# lambda x: x[1]는 (key, value) 튜플을 받아서 그 튜플의 두 번째 요소를 반환하고,
# 이를 sorted 함수의 key 인수로 전달되어 튜플의 value를 기준으로 정렬.
in_order_list = sorted(bigram_dict.items(), key=lambda x: x[1], reverse = True)
print(f"bigram 딕셔너리의 value값을 내림차순 한 결과는 다음과 같습니다 : {in_order_list}")

# 제일 많이 나온 bigram 출력하기
max_bigram_1 = in_order_list[0][0]
print(f"가장 많이 나온 bigram은: {max_bigram_1} 입니다.")

################# 바로 max값 뽑아내기

# lambda 함수를 활용하여 딕셔너리에서 바로 max의 value값을 가지는 key값 출력하기
max_bigram_2 = max(bigram_dict, key=lambda x: bigram_dict[x])
# print(f"가장 많이 나온 bigram은: {max_bigram_2} 입니다.")
# Out:
# bigram 딕셔너리는 다음과 같습니다 : {'thetesseract': 34, 'tesseracthas': 1, 'hasawakened': 1, 'awakenedit': 1, 'itis': 5, 'ison': 3, 'ona': 3, 'aneutral': 1, 'neutralworld': 1, 'worlda': 1, 'ahuman': 1, 'humanworld': 1, 'worldthey': 2, 'theywield': 1, 'wieldits': 1, 'itspower': 1, 'powerbut': 1, 'butour': 1, 'ourally': 1, 'allyknows': 1, 'knowsit': 3, 'its': 68, 'sworking': 1, 'working
4, 'bea': 7, 'aminimum': 1, 'minimumsafe': 1, 'safedistance': 1, 'distancei': 1, 'ineed': 9, 'needyou': 7, 'youto': 11, 'tomake': 4, 'makesure': 1, 'surethat': 1, 'thatphase': 1, 'phasesir': 1, 'siris': 1, 'isthat': 5, 'thatreally': 1, 'reallya': 1, 'apriority': 1, 'priorityright': 1, 'rightnow': 5, 'nowuntil': 1, 'untilsuch': 1, 'suchtime': 1, 'timeas': 2, 'asthe': 1, 'worldends': 1, 'endswe': 1, 'wewill': 2, 'willact': 1, 'actas': 1, 'asthough': 1, 'thoughit': 1, 'itintends': 1, 'intendsto': 1, 'tospin': 1, 'spinon': 1, 'onclear': 1, 'clearout': 1, 'outthe': 3, 'thetech': 1, 'techbelow': 1, 'belowevery': 1, 'everypiece': 1, 'pieceof': 1, 'ofphase': 1, 'phase2': 5, '2on': 1, 'atruck': 1, 'truckand': 1, 'andgone': 1, 'goneyes': 1, 'yessir': 3, 'sircome': 1, 'comewith': 2, 'withme': 1, 'metalk': 1, 'talkto': 4, 'tome': 5, 'medoctor': 1, 'doctordirector': 1, 'directoris': 1, 'isthere': 2, 'thereanything': 2, 'anythingwe': 2, 'weknow': 1, 'knowfor': 2, 'forcertain': 1, 'certaintesseract': 1, 'tesseractis': 8, 'ismisbehaving': 1, 'misbehavingis': 1, 'thatsupposed': 1, 'supposedto': 3, 'tobe': 17, 'befunny': 1, 'funnyno': 2, 'noit': 4, 'snot': 15, 'notfunny': 1, 'funnyat': 1, 'atall': 1, 'allthe': 7, 'isnot': 5, 'notonly': 2, 'onlyactive': 1, 'activeshe': 1, 'shes': 3, 'smisbehaving': 1, 'misbehavinghow': 1, 'howsoon': 1, 'soonuntil': 1, 'untilyou': 3, 'youpull': 1, 'theplug': 1, 'plugshe': 1, 'san': 5, 'energysource': 2, 'sourceif': 2, 'weturn':  ...
# bigram 딕셔너리의 value값을 내림차순 한 결과는 다음과 같습니다 : [('its', 68), ('im', 52), ('dont', 43), ('youre', 35), ('thetesseract', 34), ('hes', 32), ('didnt', 26), ('thats', 25), ('onthe', 25), ('were', 25), ('inthe', 24), ('idon', 22), ('areyou', 20), ('thisis', 20), ('youknow', 20), ('cant', 19), ('tobe', 17), ('ive', 16), ('doyou', 16), ('sa', 16), ('snot', 15), ('ofthe', 14), ('thecube', 14), ('tothe', 14), ('youcan', 14), ('iwas', 14), ('andi', 13), ('outof', 13), ('isnt', 13), ('youve', 13), ('theres', 13), ('ina', 13), ('theworld', 12), ('tknow', 12), ('ican', 12), ('isa', 12), ('ill', 12), ('lokis', 12), ('toget', 11), ('youto', 11), ('youhave', 11), ('weneed', 11), ('id', 11), ('sgonna', 11), ('andyou', 11), ('didyou', 10), ('ithink', 10), ('gota', 10), ('ididn', 10), ('alittle', 10), ('whatare', 9), ('ineed', 9), ('ihave', 9), ('alot', 9), ('hewants', 9), ('whatyou', 9), ('needa', 9), ('mnot', 9), ('forthe', 9), ('igot', 9), ('drbanner', 9), ('sthe', 8), ('ifwe', 8), ('wecan', 8), ('tesseractis', 8), ('thave', 8), ('theother', 8), ('haveto', 8), ('wehave', 8), ('kindof', 8), ('tellme', 8), ('nono', 8), ('needto', 8), ('vegot', 8), ('youand', 8), ('theavengers', 8), ('regonna', 8), ('foryou', 8), ('youneed', 8), ('isthis', 8), ('youwere', 8), ('wegot', 8), ('knowwhat', 8), ('renot', 8), ('andthe', 7), ('bea', 7), ('needyou', 7), ('allthe', 7), ('havea', 7), ('hewas', 7), ('withthe', 7), ('donot', 7), ('thatwe', 7), ('ithought', 7), ('toyou', 7), ('youon', 7), ('meto', 7), ('likeyou', 7), ('aboutthe', 7), ('whatwe', 7), ('lets', 7), ('iknow', 7), ('likea', 7), ('youi', 7), ('youthink', 7), ('agentromanoff', 7), ('theonly', 7), ('whats', 7), ('wedon', 6), ('fromthe', 6), ('shouldbe', 6), ('offthe', 6), ('agentbarton', 6), ('doesnt', 6), ('iam', 6), ('ofa', 6), ('youwill', 6), ('thinkyou', 6), ('lotof', 6), ('ido', 6), ('sjust', 6), ('doi', 6), ('iwill', 6), ('ofthis', 6), ('shouldhave', 6), ('aman', 6), ('ifi', 6), ('tthink', 6), ('youwanna', 6), ('isthe', 6), ('msorry', 6), ('ijust', 6), ('youshould', 6), ('thinki', 6), ('theway', 6), ('well', 6), ('youyou', 6), ('gonnabe', 6), ('canyou', 6), ('thankyou', 6), ('thati', 6), ('imean', 6), ('thatthe', 6), ('ami', 6), ('butyou', 6), ('itis', 5), ('sirwe', 5), ('itdown', 5), ('isthat', 5), ('rightnow', 5), ('phase2', 5), ('tome', 5), ('isnot', 5), ('san', 5), ('weve', 5), ('havethe', 5), ('wheres', 5), ('mei', 5), ('theportal', 5), ('yougot', 5), ('whos', 5), ('gotthe', 5), ('iwant', 5), ('weare', 5), ('toknow', 5), ('tocome', 5), ('youget', 5), ('knowthat', 5), ('starkyou', 5), ('mewe', 5), ('otherguy', 5), ('tryto', 5), ('todo', 5), ('stoo', 5), ('thatwas', 5), ('youdon', 5), ('lokihe', 5), ('upto', 5), ('timei', 5), ('nowyou', 5), ('therest', 5), ('welli', 5), ('goingto', 5), ('starkwe', 5), ('knowi', 5), ('mea', 5), ('guys', 5), ('theearth', 5), ('forme', 5), ('notthe', 5), ('theguy', 5), ('whatit', 5), ('noneof', 5), ('herei', 5), ('swhat', 5), ('butit', 5), ('liketo', 5), ('rea', 5), ('downwe', 4), ('themto', 4), ('togo', 4), ('backto', 4), ('notbe', 4), ('tomake', 4), ('talkto', 4), ('noit', 4), ('canbe', 4), ('soyou', 4), ('noi', 4), ('therewas', 4), ('atthis', 4), ('ti', 4), ('itdoes', 4), ('ofasgard', 4), ('youmean', 4), ('aboutto', 4), ('meansto', 4), ('sgot', 4), ('knowhow', 4), ('howmany', 4), ('forthat', 4), ('wedo', 4), ('youmay', 4), ('putthe', 4), ('comein', 4), ('buthe', 4), ('comehere', 4), ('andhe', 4), ('aspy', 4), ('idid', 4), ('hereto', 4), ('howdid', 4), ('tget', 4), ('itwell', 4), ('sno', 4), ('wherei', 4), ('onthis', 4), ('whereyou', 4), ('youever', 4), ('nota', 4), ('toa', 4), ('buti', 4), ('tryingto', 4), ('saveit', 4), ('aroundhere', 4), ('ifyou', 4), ('arewe', 4), ('howdoes', 4), ('iremember', 4), ('allthis', 4), ('twelvepercent', 4), ('onyou', 4), ('arent', 4), ('tellyou', 4), ('mrstark', 4), ('wewere', 4), ('tyou', 4), ('onme', 4), ('slike', 4), ('igotta', 4), ('tohave', 4), ('youare', 4), ('theyre', 4), ('geta', 4), ('toput', 4), ('thereis', 4), ('whatdid', ...
# 가장 많이 나온 bigram은: its 입니다.

# %% [markdown]
# # 회고
# 1. file을 불러오는 구문을 작성해 본 것은 처음이라 조금 헤맸었지만
# google drive와 연동성이 좋아서 생각보다는 수월하게 진행한것 같다.
# 2. 특수기호를 없애는 과정에서 처음에는 replace 구문을 일일이 만들었는데
# ex.(```lowertext.replace(',',' ')
#    lowertext.replace('?',' ')```)
#    검색해보니 연속하여 replace를 붙일 수 있다는 것을 알게되었고, 이를 통해  코드를 간소화할 수 있었다.
# 3. 특수 기호 중 '\\'은 replace('\\')를 하니 \가 excaping character이라
#    에러가 났다. '\\' 특수기호를 표현하려면 '\\\\'를 써주어야 한다는 것을 배웠다
# 4. split하는 과정에서 ' '(한개의 띄워쓰기)를 사용했는데 이렇게 되면 여러개의 연속되는 띄어쓰기의 경우, 중복되는 띄어쓰기가 결과값으로 분할이 되어 나오는 버그가 발생하였다. chatGPT의 도움을 받은 결과, re모듈을 사용하여 ```re.split()```함수를 사용하고, ```r'\s+'```(여러개의 띄어쓰기를 하나의 구분자로 설정)을 사용하는 구문을 알게되어 적용하였다.
# 5. 딕셔너리를 만든 뒤, value값을 기준으로 max값을 뽑아야 하는데 방법을 모르곘어서 또 다시 chatGPT의 도움을 받았다...
# 그 똑똑한 친구가 lambda함수의 사용법을 알려주었고, 이를 통해 내림차순 하는 방법, max값을 봅아내는 방법을 배웠다.
#
# ##최종
# 내 힘으로 할 수 없는 부분을 서로 도와가면서 해결할 수 있어서 좋았으나
# 여전히 모르는것이 많아서 똑똒한 친구(chatGPT)의 도움을 받을 수 밖에 없었다.
# 그러나 오늘 배운 것은 다시 도움받을 일 없도록 내것으로 만들고야 말겠다.
